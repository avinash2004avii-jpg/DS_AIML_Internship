# %%
pip install pandas notebook
# Out:
# ...
#
#    ------------- -------------------------- 2/6 [lark]
#    ------------- -------------------------- 2/6 [lark]
#    -------------------------- ------------- 4/6 [rfc3987-syntax]
#    ---------------------------------------- 6/6 [isoduration]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter note book
